# %%
import statsmodels.formula.api as smf
import statsmodels as sm
import matplotlib.pyplot as plt

from data_utils import load_pickle
from plot_utils import *

# %%
full_model = load_pickle('full_model.pkl')

# %%
plt.figure(figsize=[22, 6])
plot_coefs(full_model)

# %%
gender_model = load_pickle('gender_model.pkl')

# %%
plot_gender(gender_model)

# %%
gender_occupation_model = load_pickle('models/gender_occupation_model.pkl')

# %%
plt.figure(figsize=[6.4 * 3, 4.8])
plot_gender_occupations(gender_occupation_model)

# %%
party_model = load_pickle('models/party_model.pkl')

# %%
plt.figure(figsize=[6.4 * 2, 4.8])
plot_party(party_model)
